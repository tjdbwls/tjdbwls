# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdbwls/tjdbwls/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7655 sha256=57fc6cbe8321d9683a0ffaf500e8fd5791af0666879d0addecd22441436db65b
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import*
initializeTurtle()

for i in range(5):
  color('red')
  right(144)
  forward(50)
  color('yellow')
  forward(50)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
import numpy as np

goto(350,200)

initializeTurtle()
r = 100
for i in range(100):
  angle = (2 * np.pi)/100 * i
  x = 350+r * np.cos(angle)
  y = 200+r * np.sin(angle)
  goto(x,y)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
